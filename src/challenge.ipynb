# %% [markdown]
# # **Challenge LATAM**

# %% [markdown]
# En este documento se encuentra la descripción detallada de cada uno de los puntos del challenge. Como se pensaron las soluciones los tiempos y memoria utilizada.

# %% [markdown]
# # Memory-Optimized Version of q1_memory Function

# %% [markdown]
# ## Overview
# Esta función está diseñada para analizar datos de tweets y extraer información sobre las fechas principales con más tweets y los usuarios con más publicaciones para cada una de estas fechas. El código está optimizado para la eficiencia de la memoria.
#
# ## Dependencies
# - Python 3.x
# - pandas
# - memory-profiler (for memory profiling)
#
# ## Function Signature
# ```python
# def q1_memory(file_path: str) -> List[Tuple[datetime.date, str]]:

# %% [markdown]
# ## Parameters
# - `file_path` (str): El camino al archivo JSON que contiene los datos de los tweets.
#
# ## Return Value
# - Lista de Tuplas: Cada tupla contiene una fecha (objeto datetime.date) y el nombre de usuario (str) con más publicaciones en esa fecha.
#
# ## Memory Optimization Techniques
# 1. **Carga directa del DataFrame:** El DataFrame se carga directamente desde el archivo JSON sin operaciones de agrupamiento innecesarias.
# 2. **Filtrado eficiente de fechas:** Las fechas con más tweets se identifican usando `value_counts().head(10)`, optimizando el uso de memoria.
# 3. **Operaciones vectorizadas:** Uso de operaciones vectorizadas como `isin` y `groupby` para una manipulación eficiente de datos.
# 4. **Creación mínima de DataFrames:** Los DataFrames se crean solo cuando es necesario para minimizar el consumo de memoria.

# %% [markdown]
# ## Memory Profiling

# %%
from typing import List, Tuple
from datetime import datetime
from utils import load_json_as_df
import pandas as pd
import psutil

def q1_memory(file_path: str) -> List[Tuple[datetime.date, str]]:
    # Obtener el uso de memoria antes de cargar el DataFrame
    memory_before = psutil.Process().memory_info().rss / 1024 ** 2  # en MB

    # Cargar el DataFrame directamente en lugar de cargarlo y luego agruparlo
    df = load_json_as_df(file_path, include_date=True)

    # Obtener el uso de memoria después de cargar el DataFrame
    memory_after_load = psutil.Process().memory_info().rss / 1024 ** 2  # en MB

    # Obtener las fechas con más tweets directamente sin agrupar todo el DataFrame
    top_dates = df['date'].value_counts().head(10).index

    # Filtrar el DataFrame solo para las fechas con más tweets
    top_df = df[df['date'].isin(top_dates)]

    # Obtener el uso de memoria después de filtrar el DataFrame
    memory_after_filter = psutil.Process().memory_info().rss / 1024 ** 2  # en MB

    # Obtener los usuarios con más publicaciones para cada fecha top
    top_users = top_df.groupby('date')['username'].agg(lambda x: x.value_counts().idxmax()).reset_index()

    # Convertir las fechas a objetos datetime.date
    top_users['date'] = pd.to_datetime(top_users['date']).dt.date

    # Obtener el uso de memoria después de crear el DataFrame final
    memory_after_final_df = psutil.Process().memory_info().rss / 1024 ** 2  # en MB

    # Obtener el resultado final como una lista de tuplas
    result = list(top_users.itertuples(index=False, name=None))

    # Imprimir información sobre el uso de memoria
    print(f"Uso de memoria antes de cargar el DataFrame: {memory_before} MB")
    print(f"Uso de memoria después de cargar el DataFrame: {memory_after_load} MB")
    print(f"Uso de memoria después de filtrar el DataFrame: {memory_after_filter} MB")
    print(f"Uso de memoria después de crear el DataFrame final: {memory_after_final_df} MB")

    return result

if __name__ == "__main__":
    result = q1_memory(r'C:\Users\wppaez\Desktop\challenge_LATAM\input\farmers-protest-tweets-2021-2-4.json')
    print(result)
# Out:
# Uso de memoria antes de cargar el DataFrame: 108.78125 MB
# Uso de memoria después de cargar el DataFrame: 120.875 MB
# Uso de memoria después de filtrar el DataFrame: 123.41796875 MB
# Uso de memoria después de crear el DataFrame final: 122.73046875 MB
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'), (datetime.date(2021, 2, 13), 'MaanDee08215437'), (datetime.date(2021, 2, 14), 'rebelpacifist'), (datetime.date(2021, 2, 15), 'jot__b'), (datetime.date(2021, 2, 16), 'jot__b'), (datetime.date(2021, 2, 17), 'RaaJVinderkaur'), (datetime.date(2021, 2, 18), 'neetuanjle_nitu'), (datetime.date(2021, 2, 19), 'Preetm91'), (datetime.date(2021, 2, 20), 'MangalJ23056160'), (datetime.date(2021, 2, 23), 'Surrypuria')]

# %% [markdown]
# # Time-Optimized Version of q1_time Function
#
# Esta función se utiliza para obtener las fechas con más tweets y los usuarios con más publicaciones para cada fecha a partir de un archivo JSON con datos de tweets.
#
# ## Parameters
#
# - `file_path` (str): Ruta del archivo JSON con los datos de los tweets.
#
# ## Return value
#
# Lista de tuplas que contiene la fecha y el usuario con más publicaciones para esa fecha.
#
# ## Usage
#
# ```python
# result = q1_time('./input/farmers-protest-tweets-2021-2-4.json')
# print(result)

# %% [markdown]
# ## Time Optimization Techniques
#
# 1. Carga el DataFrame directamente en lugar de cargarlo y luego agruparlo.
# 2. Obtiene las fechas con más tweets directamente sin agrupar todo el DataFrame.
# 3. Filtra el DataFrame solo para las fechas con más tweets.
# 4. Obtiene los usuarios con más publicaciones para cada fecha top.
# 5. Convierte las fechas a objetos datetime.date.
# 6. Retorna el resultado final como una lista de tuplas.

# %%
import cProfile
from datetime import datetime
from utils import load_json_as_df
import pandas as pd

def q1_time(file_path: str):
    """
    Función para obtener las fechas con más tweets y los usuarios con más publicaciones
    para cada fecha a partir de un archivo JSON con datos de tweets.

    Args:
        file_path (str): Ruta del archivo JSON con los datos de los tweets.
    """

    # Cargar el DataFrame directamente en lugar de cargarlo y luego agruparlo
    df = load_json_as_df(file_path, include_date=True)

    # Obtener las fechas con más tweets directamente sin agrupar todo el DataFrame
    top_dates = df['date'].value_counts().nlargest(10).index

    # Filtrar el DataFrame solo para las fechas con más tweets
    top_df = df[df['date'].isin(top_dates)]

    # Obtener los usuarios con más publicaciones para cada fecha top
    top_users = top_df.groupby('date')['username'].apply(lambda x: x.mode().iloc[0]).reset_index()

    # Convertir las fechas a objetos datetime.date
    top_users['date'] = pd.to_datetime(top_users['date']).dt.date

    # Obtener el resultado final como una lista de tuplas
    result = list(top_users.itertuples(index=False, name=None))

    return result

# Ruta del archivo JSON con los datos de los tweets
file_path = r'C:\Users\wppaez\Desktop\challenge_LATAM\input\farmers-protest-tweets-2021-2-4.json'

# Crea un perfilador
profiler = cProfile.Profile()

# Inicia el perfilador
profiler.enable()

# Ejecuta la función que quieres medir
result = q1_time(file_path)

# Detén el perfilador
profiler.disable()

# Muestra las estadísticas del perfilador
profiler.print_stats(sort='time')
# Out:
#          4689027 function calls (4688182 primitive calls) in 14.651 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    117407    4.813    0.000    4.813    0.000 decoder.py:343(raw_decode)
#         1    2.799    2.799   14.491   14.491 utils.py:6(load_json_as_df)
#    117407    2.666    0.000    4.626    0.000 _strptime.py:309(_strptime)
#    117407    0.636    0.000    5.262    0.000 _strptime.py:565(_strptime_datetime)
#    352221    0.488    0.000    0.488    0.000 {method 'match' of 're.Pattern' objects}
#    117407    0.412    0.000    5.582    0.000 decoder.py:332(decode)
#    117407    0.372    0.000    0.372    0.000 {built-in method _locale.setlocale}
#    117407    0.285    0.000    5.940    0.000 __init__.py:299(loads)
#    117407    0.227    0.000    0.318    0.000 locale.py:396(normalize)
#    117407    0.199    0.000    0.199    0.000 {method 'groupdict' of 're.Match' objects}
#    117407    0.176    0.000    5.438    0.000 {built-in method strptime}
#    117407    0.144    0.000    0.954    0.000 locale.py:587(getlocale)
#    352221    0.121    0.000    0.121    0.000 {method 'end' of 're.Match' objects}
#    117407    0.120    0.000    0.438    0.000 locale.py:479(_parse_localename)
#    117407    0.117    0.000    1.071    0.000 _strptime.py:26(_getlang)
# 587535/587393    0.112    0.000    0.112    0.000 {built-in method builtins.len}
#     49772    0.104    0.000    0.208    0.000 codecs.py:319(decode)
#     49772    0.104    0.000    0.104    0.000 {built-in method _codecs.utf_8_decode}
#    352238    0.104    0.000    0.104    0.000 {method 'get' of 'dict' objects}
#    234814    0.100    0.000    0.100    0.000 {method 'startswith' of 'str' objects}
# 354088/354077    0.063    0.000    0.074    0.000 {built-in method builtins.isinstance}
# 118067/117407    0.056    0.000    0.066    0.000 {method 'keys' of 'dict' objects}
#    234814    0.054    0.000    0.054    0.000 {method 'toordinal' of 'datetime.date' objects}
#    117407    0.042    0.000    0.042    0.000 {method 'lower' of 'str' objects}
#    117407    0.039    0.000    0.039    0.000 {method '__exit__' of '_thread.lock' objects}
#        10    0.035    0.003    0.038    0.004 algorithms.py:1023(mode)
#    117426    0.031    0.000    0.031    0.000 {method 'append' of 'list' objects}
#    117407    0.028    0.000    0.028    0.000 {method 'date' of 'datetime.datetime' objects}
#    117407    0.025    0.000    0.025    0.000 {method 'weekday' of 'datetime.date' objects}
#         1    0.023    0.023    0.023    0.023 construction.py:849(_list_to_arrays)
#         1    0.014    0.014    0.014    0.014 algorithms.py:963(value_counts_arraylike)
#      18/4    0.011    0.001    0.011    0.003 {built-in method _abc._abc_subclasscheck}
#         1    0.010    0.010    0.010    0.010 algorithms.py:548(factorize_array)
#         1    0.009    0.009   14.650   14.650 4249762235.py:1(<module>)
#         1    0.008    0.008   14.641   14.641 4249762235.py:6(q1_time)
#         5    0.006    0.001    0.009    0.002 take.py:120(_take_nd_ndarray)
#         1    0.005    0.005    0.027    0.027 selectn.py:90(compute)
#         1    0.004    0.004    0.045    0.045 frame.py:683(__init__)
#         1    0.004    0.004    0.004    0.004 algorithms.py:457(isin)
#         1    0.003    0.003    0.004    0.004 managers.py:2244(_stack_arrays)
#        34    0.003    0.000    0.003    0.000 {built-in method numpy.empty}
#       330    0.003    0.000    0.010    0.000 ipkernel.py:770(_clean_thread_parent_frames)
#         1    0.003    0.003    0.006    0.006 base.py:7031(drop)
#        10    0.002    0.000    0.002    0.000 {method 'sort' of 'numpy.ndarray' objects}
#       165    0.002    0.000    0.003    0.000 threading.py:1478(enumerate)
#       990    0.002    0.000    0.002    0.000 threading.py:1145(ident)
#         4    0.002    0.000    0.002    0.000 {method 'take' of 'numpy.ndarray' objects}
#         1    0.002    0.002    0.066    0.066 groupby.py:1850(_python_apply_general)
#        17    0.002    0.000    0.006    0.000 series.py:389(__init__)
#         1    0.002    0.002    0.006    0.006 managers.py:2188(_form_blocks)
#       165    0.002    0.000    0.004    0.000 ipkernel.py:785(<setcomp>)
#         1    0.001    0.001    0.001    0.001 function_base.py:5173(delete)
#         1    0.001    0.001    0.002    0.002 {built-in method io.open}
#         3    0.001    0.000    0.001    0.000 utils.py:239(maybe_convert_indices)
#         1    0.001    0.001    0.029    0.029 series.py:4145(nlargest)
#         4    0.001    0.000    0.001    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.011    0.011 concat.py:405(__init__)
#         1    0.001    0.001    0.001    0.001 construction.py:532(treat_as_nested)
#        16    0.001    0.000    0.004    0.000 base.py:475(__new__)
#         1    0.001    0.001    0.001    0.001 sorting.py:644(get_group_index_sorter)
#         1    0.001    0.001    0.001    0.001 missing.py:261(_isna_array)
#        15    0.001    0.000    0.001    0.000 common.py:1596(pandas_dtype)
#        13    0.001    0.000    0.001    0.000 cast.py:1157(maybe_infer_to_datetimelike)
#        24    0.001    0.000    0.002    0.000 common.py:1434(_is_dtype_type)
#         1    0.001    0.001    0.028    0.028 selectn.py:55(nlargest)
#        26    0.001    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        21    0.001    0.000    0.001    0.000 config.py:635(_get_root)
#         1    0.001    0.001    0.001    0.001 dataclasses.py:1211(is_dataclass)
#        43    0.001    0.000    0.001    0.000 generic.py:278(__init__)
#         2    0.001    0.000    0.001    0.000 concat.py:52(concat_compat)
#         1    0.001    0.001    0.001    0.001 inference.py:404(is_dataclass)
#         1    0.001    0.001    0.013    0.013 concat.py:157(concat)
#         1    0.001    0.001    0.001    0.001 generic.py:378(_wrap_applied_output)
#         1    0.001    0.001    0.068    0.068 groupby.py:1780(apply)
#         6    0.001    0.000    0.001    0.000 warnings.py:458(__enter__)
#         1    0.001    0.001    0.002    0.002 series.py:3678(sort_values)
#        21    0.001    0.000    0.002    0.000 config.py:127(_get_single_key)
#        38    0.001    0.000    0.001    0.000 generic.py:6233(__finalize__)
#   474/471    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#         1    0.001    0.001    0.001    0.001 cast.py:1760(np_can_hold_element)
#        24    0.001    0.000    0.001    0.000 common.py:372(apply_if_callable)
#        26    0.001    0.000    0.003    0.000 construction.py:517(sanitize_array)
#         4    0.001    0.000    0.001    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.001    0.000 base.py:2313(is_unique)
#         1    0.000    0.000    0.000    0.000 config.py:471(__init__)
#        28    0.000    0.000    0.001    0.000 base.py:649(_simple_new)
#        10    0.000    0.000    0.001    0.000 range.py:137(__new__)
#        19    0.000    0.000    0.003    0.000 config.py:145(_get_option)
#         1    0.000    0.000    0.002    0.002 base.py:6916(delete)
#         3    0.000    0.000    0.001    0.000 cast.py:124(maybe_convert_platform)
#         5    0.000    0.000    0.001    0.000 cast.py:551(maybe_promote)
#        21    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#        40    0.000    0.000    0.003    0.000 base.py:7593(ensure_index)
#         4    0.000    0.000    0.000    0.000 base.py:456(_engine_type)
#         2    0.000    0.000    0.001    0.000 construction.py:1028(convert)
#        71    0.000    0.000    0.001    0.000 generic.py:6298(__setattr__)
#         1    0.000    0.000    0.001    0.001 frame.py:9028(groupby)
#         1    0.000    0.000    0.000    0.000 base.py:6394(_should_compare)
#         1    0.000    0.000    0.000    0.000 _asarray.py:27(require)
#        22    0.000    0.000    0.000    0.000 numeric.py:274(full)
#         1    0.000    0.000    0.001    0.001 sorting.py:369(nargsort)
#        12    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        10    0.000    0.000    0.043    0.004 4249762235.py:25(<lambda>)
#       330    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.020    0.020 base.py:923(value_counts)
#         2    0.000    0.000    0.001    0.000 config.py:153(_set_option)
#         7    0.000    0.000    0.013    0.002 frame.py:4050(__getitem__)
#         1    0.000    0.000    0.019    0.019 algorithms.py:862(value_counts_internal)
#       312    0.000    0.000    0.001    0.000 generic.py:42(_instancecheck)
#         1    0.000    0.000    0.000    0.000 config.py:688(_warn_if_deprecated)
#        11    0.000    0.000    0.006    0.001 ops.py:1149(__iter__)
#        21    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#         1    0.000    0.000    0.001    0.001 grouper.py:846(get_grouper)
#       312    0.000    0.000    0.000    0.000 generic.py:37(_check)
#         1    0.000    0.000    0.000    0.000 managers.py:2015(_can_hold_na)
#         2    0.000    0.000    0.001    0.000 base.py:3820(get_indexer)
#        27    0.000    0.000    0.000    0.000 series.py:703(dtype)
#         1    0.000    0.000    0.007    0.007 generic.py:4793(_drop_axis)
#         2    0.000    0.000    0.001    0.001 groupby.py:1296(__init__)
#         2    0.000    0.000    0.001    0.000 datetimes.py:329(_from_sequence_not_strict)
#        11    0.000    0.000    0.000    0.000 base.py:5323(__contains__)
#         4    0.000    0.000    0.001    0.000 base.py:842(_engine)
#        11    0.000    0.000    0.000    0.000 managers.py:1972(get_slice)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#        10    0.000    0.000    0.042    0.004 series.py:2275(mode)
#         1    0.000    0.000    0.026    0.026 construction.py:506(nested_data_to_arrays)
#        43    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#        24    0.000    0.000    0.011    0.000 {built-in method _abc._abc_instancecheck}
#        14    0.000    0.000    0.001    0.000 indexing.py:1719(_getitem_axis)
#         1    0.000    0.000    0.000    0.000 datetimes.py:2354(objects_to_datetime64)
#         1    0.000    0.000    0.001    0.001 datetimes.py:314(_convert_listlike_datetimes)
#         1    0.000    0.000    0.063    0.063 ops.py:897(apply_groupwise)
#         1    0.000    0.000    0.002    0.002 construction.py:928(_finalize_columns_and_data)
#        18    0.000    0.000    0.001    0.000 managers.py:1861(from_array)
#        12    0.000    0.000    0.001    0.000 algorithms.py:106(_ensure_data)
#        92    0.000    0.000    0.000    0.000 range.py:999(__len__)
#         1    0.000    0.000    0.000    0.000 datetimes.py:1436(date)
#        47    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.025    0.025 construction.py:793(to_arrays)
#        27    0.000    0.000    0.000    0.000 managers.py:1991(dtype)
#        14    0.000    0.000    0.002    0.000 indexing.py:1176(__getitem__)
#        47    0.000    0.000    0.000    0.000 series.py:730(name)
#         1    0.000    0.000    0.007    0.007 construction.py:96(arrays_to_mgr)
#         4    0.000    0.000    0.001    0.000 common.py:231(asarray_tuplesafe)
#         9    0.000    0.000    0.000    0.000 _methods.py:55(_any)
#         3    0.000    0.000    0.000    0.000 cast.py:1577(construct_1d_object_array_from_listlike)
#        32    0.000    0.000    0.000    0.000 generic.py:571(_get_axis_number)
#         6    0.000    0.000    0.000    0.000 managers.py:1012(iget)
#         1    0.000    0.000    0.010    0.010 frame.py:4118(_getitem_bool_array)
#        18    0.000    0.000    0.000    0.000 blocks.py:2716(new_block)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.000    0.000    0.002    0.002 construction.py:950(_validate_or_indexify_columns)
#         2    0.000    0.000    0.000    0.000 datetimes.py:304(_simple_new)
#     56/55    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#        38    0.000    0.000    0.000    0.000 flags.py:87(allows_duplicate_labels)
#         3    0.000    0.000    0.000    0.000 api.py:386(default_index)
#        18    0.000    0.000    0.000    0.000 generic.py:806(_set_axis)
#        13    0.000    0.000    0.000    0.000 range.py:201(_simple_new)
#         6    0.000    0.000    0.000    0.000 series.py:1462(_set_as_cached)
#        41    0.000    0.000    0.000    0.000 managers.py:2002(internal_values)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#        17    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 base.py:1730(_get_default_index_names)
#        20    0.000    0.000    0.000    0.000 blocks.py:2645(maybe_coerce_values)
#         3    0.000    0.000    0.012    0.004 generic.py:4024(take)
#        27    0.000    0.000    0.000    0.000 series.py:780(name)
#        19    0.000    0.000    0.000    0.000 generic.py:6281(__getattr__)
#         6    0.000    0.000    0.001    0.000 frame.py:4614(_get_item_cache)
#         2    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.011    0.011 algorithms.py:610(factorize)
#        46    0.000    0.000    0.000    0.000 base.py:7688(maybe_extract_name)
#        16    0.000    0.000    0.000    0.000 series.py:664(_constructor_from_mgr)
#       165    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        83    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#        43    0.000    0.000    0.000    0.000 construction.py:416(extract_array)
#        21    0.000    0.000    0.000    0.000 generic.py:585(_get_axis)
#         3    0.000    0.000    0.000    0.000 base.py:5552(equals)
#         3    0.000    0.000    0.011    0.004 managers.py:869(take)
#         1    0.000    0.000    0.000    0.000 numeric.py:136(ones)
#        10    0.000    0.000    0.002    0.000 fromnumeric.py:865(sort)
#         1    0.000    0.000    0.002    0.002 indexing.py:2632(check_bool_indexer)
#        12    0.000    0.000    0.000    0.000 common.py:1331(is_ea_or_datetimelike_dtype)
#        28    0.000    0.000    0.000    0.000 common.py:1571(validate_all_hashable)
#         4    0.000    0.000    0.000    0.000 base.py:5170(_get_engine_target)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:262(__subclasshook__)
#         4    0.000    0.000    0.009    0.002 managers.py:623(reindex_indexer)
#        10    0.000    0.000    0.001    0.000 ops.py:1171(_chop)
#        13    0.000    0.000    0.000    0.000 algorithms.py:184(_reconstruct_data)
#         1    0.000    0.000    0.000    0.000 datetimes.py:126(_guess_datetime_format_for_array)
#        14    0.000    0.000    0.000    0.000 indexing.py:161(iloc)
#         1    0.000    0.000    0.011    0.011 ops.py:758(_get_compressed_codes)
#         1    0.000    0.000    0.000    0.000 grouper.py:527(__init__)
#        25    0.000    0.000    0.000    0.000 generic.py:339(_from_mgr)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2184(_sequence_to_dt64)
#         1    0.000    0.000    0.000    0.000 base.py:232(__getitem__)
#        21    0.000    0.000    0.000    0.000 blocks.py:2674(get_block_type)
#         1    0.000    0.000    0.010    0.010 concat.py:494(_clean_keys_and_objs)
#         2    0.000    0.000    0.001    0.000 datetimes.py:320(__new__)
#         2    0.000    0.000    0.000    0.000 frame.py:659(_constructor_from_mgr)
#         3    0.000    0.000    0.004    0.001 managers.py:708(_slice_take_blocks_ax0)
#        13    0.000    0.000    0.000    0.000 base.py:5373(__getitem__)
#         3    0.000    0.000    0.001    0.000 missing.py:184(_isna)
#         6    0.000    0.000    0.000    0.000 base.py:609(_dtype_to_subclass)
#         1    0.000    0.000    0.000    0.000 cast.py:614(_maybe_promote)
#         1    0.000    0.000    0.013    0.013 ops.py:622(_get_splitter)
#         1    0.000    0.000    0.000    0.000 utils.py:419(check_array_indexer)
#        21    0.000    0.000    0.000    0.000 indexing.py:2765(check_dict_or_set_indexers)
#         9    0.000    0.000    0.000    0.000 base.py:82(shape)
#        16    0.000    0.000    0.002    0.000 common.py:137(is_object_dtype)
#         1    0.000    0.000    0.001    0.001 series.py:5811(dropna)
#         1    0.000    0.000    0.000    0.000 grouper.py:744(_group_index)
#        11    0.000    0.000    0.000    0.000 base.py:5425(_getitem_slice)
#        22    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#         4    0.000    0.000    0.008    0.002 blocks.py:1287(take_nd)
#         2    0.000    0.000    0.000    0.000 missing.py:728(is_valid_na_for_dtype)
#        19    0.000    0.000    0.000    0.000 common.py:97(is_bool_indexer)
#        39    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        35    0.000    0.000    0.000    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#         3    0.000    0.000    0.000    0.000 series.py:910(__len__)
#         7    0.000    0.000    0.000    0.000 common.py:1198(is_bool_dtype)
#         1    0.000    0.000    0.000    0.000 series.py:698(_can_hold_na)
#        30    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#        41    0.000    0.000    0.000    0.000 series.py:827(_values)
#         1    0.000    0.000    0.068    0.068 generic.py:224(apply)
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         6    0.000    0.000    0.000    0.000 missing.py:673(na_value_for_dtype)
#        25    0.000    0.000    0.000    0.000 construction.py:693(_sanitize_ndim)
#         2    0.000    0.000    0.000    0.000 common.py:1081(is_numeric_dtype)
#         1    0.000    0.000    0.001    0.001 range.py:1148(take)
#        18    0.000    0.000    0.000    0.000 base.py:86(_validate_set_axis)
#         1    0.000    0.000    0.001    0.001 managers.py:1347(insert)
#         2    0.000    0.000    0.001    0.000 base.py:1146(take)
#         2    0.000    0.000    0.000    0.000 numeric.py:1330(normalize_axis_tuple)
#         4    0.000    0.000    0.000    0.000 common.py:536(is_string_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:1765(_get_names)
#        86    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         5    0.000    0.000    0.001    0.000 take.py:564(_take_preprocess_indexer_and_fill_value)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:2423(ensure_arraylike_for_datetimelike)
#         1    0.000    0.000    0.001    0.001 algorithms.py:1452(safe_sort)
#         7    0.000    0.000    0.000    0.000 __init__.py:55(using_pyarrow_string_dtype)
#         1    0.000    0.000    0.000    0.000 warnings.py:130(filterwarnings)
#        94    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 base.py:3996(_check_indexing_method)
#        11    0.000    0.000    0.000    0.000 generic.py:510(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 concat.py:717(_get_concat_axis)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#        56    0.000    0.000    0.000    0.000 common.py:1590(<genexpr>)
#      18/4    0.000    0.000    0.011    0.003 abc.py:121(__subclasscheck__)
#         6    0.000    0.000    0.001    0.000 frame.py:4596(_box_col_values)
#         6    0.000    0.000    0.000    0.000 frame.py:669(_sliced_from_mgr)
#         1    0.000    0.000    0.000    0.000 _asarray.py:108(<setcomp>)
#         1    0.000    0.000    0.002    0.002 datetimes.py:673(to_datetime)
#         2    0.000    0.000    0.000    0.000 indexing.py:1689(_getitem_tuple)
#         5    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#         1    0.000    0.000    0.002    0.002 frame.py:6226(reset_index)
#         6    0.000    0.000    0.000    0.000 frame.py:672(_constructor_sliced_from_mgr)
#        41    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#        14    0.000    0.000    0.000    0.000 indexing.py:1667(_validate_integer)
#        66    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFCE0453920}
#         5    0.000    0.000    0.000    0.000 take.py:325(_get_take_nd_function)
#         1    0.000    0.000    0.000    0.000 generic.py:1825(_check_label_or_level_ambiguity)
#         1    0.000    0.000    0.002    0.002 series.py:1615(reset_index)
#        10    0.000    0.000    0.000    0.000 construction.py:763(_try_cast)
#         9    0.000    0.000    0.000    0.000 managers.py:180(blknos)
#         1    0.000    0.000    0.000    0.000 datetimes.py:835(_local_timestamps)
#         2    0.000    0.000    0.007    0.004 generic.py:4139(_take_with_is_copy)
#        39    0.000    0.000    0.000    0.000 managers.py:1835(__init__)
#         1    0.000    0.000    0.000    0.000 groupby.py:1357(__getattr__)
#         4    0.000    0.000    0.000    0.000 datetimes.py:2570(_validate_tz_from_dtype)
#         1    0.000    0.000    0.000    0.000 frame.py:12662(_reindex_for_setitem)
#         6    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#        12    0.000    0.000    0.000    0.000 indexing.py:1165(_check_deprecated_callable_usage)
#         1    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#         1    0.000    0.000    0.000    0.000 base.py:2744(inferred_type)
#        19    0.000    0.000    0.000    0.000 common.py:1040(needs_i8_conversion)
#         9    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 algorithms.py:280(_check_object_for_strings)
#         1    0.000    0.000    0.000    0.000 accessors.py:611(__new__)
#         1    0.000    0.000    0.000    0.000 accessors.py:59(__init__)
#         1    0.000    0.000    0.000    0.000 function_base.py:5369(insert)
#         3    0.000    0.000    0.001    0.000 base.py:674(_with_infer)
#        24    0.000    0.000    0.000    0.000 construction.py:732(_sanitize_str_dtypes)
#         5    0.000    0.000    0.000    0.000 common.py:529(is_string_or_object_np_dtype)
#         4    0.000    0.000    0.000    0.000 blocks.py:253(fill_value)
#         1    0.000    0.000    0.000    0.000 datetimes.py:209(_maybe_cache)
#         2    0.000    0.000    0.000    0.000 managers.py:557(copy)
#         6    0.000    0.000    0.001    0.000 frame.py:3971(_ixs)
#        18    0.000    0.000    0.000    0.000 managers.py:236(set_axis)
#         1    0.000    0.000    0.000    0.000 generic.py:1939(__getitem__)
#         4    0.000    0.000    0.000    0.000 blocks.py:292(make_block_same_class)
#         5    0.000    0.000    0.009    0.002 take.py:59(take_nd)
#         1    0.000    0.000    0.000    0.000 series.py:974(__array__)
#        43    0.000    0.000    0.000    0.000 base.py:909(__len__)
#         1    0.000    0.000    0.000    0.000 ops.py:1129(__init__)
#        22    0.000    0.000    0.000    0.000 base.py:363(ndim)
#         2    0.000    0.000    0.000    0.000 groupby.py:1340(<genexpr>)
#        19    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#        10    0.000    0.000    0.000    0.000 series.py:1064(_ixs)
#         1    0.000    0.000    0.001    0.001 base.py:6956(insert)
#         1    0.000    0.000    0.007    0.007 managers.py:2119(create_block_manager_from_column_arrays)
#         2    0.000    0.000    0.001    0.000 algorithms.py:1131(take)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2310(_construct_from_dt64_naive)
#        15    0.000    0.000    0.000    0.000 _collections_abc.py:409(__subclasshook__)
#        24    0.000    0.000    0.011    0.000 abc.py:117(__instancecheck__)
#        36    0.000    0.000    0.000    0.000 managers.py:1938(_block)
#        31    0.000    0.000    0.000    0.000 series.py:660(_constructor)
#        21    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 utils.py:62(is_list_like_indexer)
#         1    0.000    0.000    0.000    0.000 ops.py:578(__init__)
#         1    0.000    0.000    0.000    0.000 concat.py:480(_get_ndims)
#         3    0.000    0.000    0.000    0.000 common.py:1163(is_float_dtype)
#         1    0.000    0.000    0.001    0.001 datetimes.py:259(_box_as_indexlike)
#         4    0.000    0.000    0.000    0.000 common.py:572(condition)
#         4    0.000    0.000    0.000    0.000 inference.py:195(is_array_like)
#        25    0.000    0.000    0.000    0.000 construction.py:752(_maybe_repeat)
#         4    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#        17    0.000    0.000    0.000    0.000 blocks.py:718(dtype)
#         1    0.000    0.000    0.000    0.000 re.py:288(_compile)
#         1    0.000    0.000    0.001    0.001 concat.py:622(get_result)
#         1    0.000    0.000    0.000    0.000 frame.py:4259(__setitem__)
#         1    0.000    0.000    0.000    0.000 grouper.py:983(is_in_axis)
#         1    0.000    0.000    0.004    0.004 series.py:5477(isin)
#         2    0.000    0.000    0.000    0.000 frame.py:5229(_sanitize_column)
#        20    0.000    0.000    0.000    0.000 common.py:121(classes)
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         1    0.000    0.000    0.001    0.001 accessors.py:88(_delegate_property_get)
#         2    0.000    0.000    0.000    0.000 base.py:5437(_can_hold_identifiers_and_holds_name)
#         2    0.000    0.000    0.000    0.000 managers.py:317(apply)
#         3    0.000    0.000    0.000    0.000 datetimes.py:2428(maybe_convert_dtype)
#         6    0.000    0.000    0.000    0.000 base.py:591(_ensure_array)
#         3    0.000    0.000    0.000    0.000 managers.py:2318(_preprocess_slice_or_indexer)
#         6    0.000    0.000    0.000    0.000 inference.py:273(is_dict_like)
#         2    0.000    0.000    0.000    0.000 function_base.py:5563(append)
#         1    0.000    0.000    0.000    0.000 selectn.py:44(__init__)
#         1    0.000    0.000    0.000    0.000 ops.py:1191(_get_splitter)
#         3    0.000    0.000    0.000    0.000 _dtype.py:346(_name_get)
#         1    0.000    0.000    0.000    0.000 concat.py:545(_get_sample_object)
#         1    0.000    0.000    0.000    0.000 algorithms.py:262(_get_hashtable_algo)
#         2    0.000    0.000    0.000    0.000 generic.py:6659(copy)
#         1    0.000    0.000    0.001    0.001 construction.py:1006(convert_object_array)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2351(copy)
#        77    0.000    0.000    0.000    0.000 generic.py:404(flags)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#        13    0.000    0.000    0.000    0.000 algorithms.py:217(_ensure_arraylike)
#         1    0.000    0.000    0.000    0.000 managers.py:1066(iset)
#         6    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#         2    0.000    0.000    0.000    0.000 managers.py:586(<listcomp>)
#         1    0.000    0.000    0.007    0.007 generic.py:4754(drop)
#         1    0.000    0.000    0.000    0.000 ops.py:782(result_index)
#         2    0.000    0.000   14.650    7.325 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 types.py:176(__get__)
#         1    0.000    0.000    0.000    0.000 frame.py:1547(itertuples)
#         2    0.000    0.000   14.650    7.325 interactiveshell.py:3541(run_code)
#        16    0.000    0.000    0.000    0.000 common.py:1399(_get_dtype)
#        39    0.000    0.000    0.000    0.000 flags.py:55(allows_duplicate_labels)
#        38    0.000    0.000    0.000    0.000 generic.py:362(attrs)
#         1    0.000    0.000    0.000    0.000 managers.py:1873(to_2d_mgr)
#         1    0.000    0.000    0.000    0.000 managers.py:1402(_insert_update_mgr_locs)
#         9    0.000    0.000    0.000    0.000 common.py:1375(_is_dtype)
#         1    0.000    0.000    0.000    0.000 numeric.py:1393(moveaxis)
#         8    0.000    0.000    0.000    0.000 _validators.py:226(validate_bool_kwarg)
#         1    0.000    0.000    0.011    0.011 grouper.py:777(_codes_and_uniques)
#         2    0.000    0.000    0.000    0.000 blocks.py:790(copy)
#         1    0.000    0.000    0.000    0.000 series.py:689(_constructor_expanddim_from_mgr)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         4    0.000    0.000    0.000    0.000 managers.py:1848(from_blocks)
#         2    0.000    0.000    0.000    0.000 contextlib.py:102(__init__)
#         3    0.000    0.000    0.000    0.000 managers.py:583(copy_func)
#         2    0.000    0.000    0.000    0.000 indexing.py:1032(_getitem_lowerdim)
#         2    0.000    0.000    0.000    0.000 managers.py:1770(_consolidate_check)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:861(_sort_dispatcher)
#        35    0.000    0.000    0.000    0.000 base.py:5144(_values)
#         1    0.000    0.000    0.000    0.000 series.py:2074(to_frame)
#        49    0.000    0.000    0.000    0.000 typing.py:1737(cast)
#         2    0.000    0.000    0.000    0.000 codeop.py:117(__call__)
#         1    0.000    0.000    0.000    0.000 generic.py:1953(_gotitem)
#         1    0.000    0.000    0.000    0.000 warnings.py:165(simplefilter)
#         1    0.000    0.000    0.001    0.001 frame.py:5082(insert)
#         1    0.000    0.000    0.000    0.000 cast.py:525(ensure_dtype_can_hold_na)
#         1    0.000    0.000    0.000    0.000 accessor.py:220(__get__)
#         3    0.000    0.000    0.000    0.000 range.py:553(equals)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:53(_wrapfunc)
#        20    0.000    0.000    0.000    0.000 common.py:123(<lambda>)
#         3    0.000    0.000    0.000    0.000 blocks.py:2811(ensure_block_shape)
#        22    0.000    0.000    0.000    0.000 base.py:84(<genexpr>)
#         1    0.000    0.000    0.001    0.001 ops.py:939(_sort_idx)
#         4    0.000    0.000    0.000    0.000 base.py:773(_view)
#         1    0.000    0.000    0.000    0.000 base.py:1809(set_names)
#         1    0.000    0.000    0.001    0.001 config.py:479(__enter__)
#         2    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#        14    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         3    0.000    0.000    0.001    0.000 missing.py:101(isna)
#        18    0.000    0.000    0.000    0.000 inference.py:300(<genexpr>)
#        39    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#        12    0.000    0.000    0.000    0.000 common.py:152(cast_scalar_indexer)
#         2    0.000    0.000    0.000    0.000 managers.py:1762(is_consolidated)
#        10    0.000    0.000    0.000    0.000 series.py:1054(axes)
#         2    0.000    0.000    0.000    0.000 base.py:2794(_na_value)
#         6    0.000    0.000    0.000    0.000 blocks.py:1253(iget)
#         3    0.000    0.000    0.000    0.000 generic.py:591(_get_block_manager_axis)
#         1    0.000    0.000    0.000    0.000 managers.py:1412(_insert_update_blklocs_and_blknos)
#         2    0.000    0.000    0.000    0.000 managers.py:948(from_blocks)
#         1    0.000    0.000    0.000    0.000 _validators.py:354(validate_ascending)
#         2    0.000    0.000    0.000    0.000 managers.py:2175(_grouping_func)
#         6    0.000    0.000    0.000    0.000 generic.py:666(_info_axis)
#         3    0.000    0.000    0.000    0.000 generic.py:2076(__contains__)
#         1    0.000    0.000    0.005    0.005 managers.py:687(<listcomp>)
#         2    0.000    0.000    0.000    0.000 common.py:301(maybe_iterable_to_list)
#         3    0.000    0.000    0.000    0.000 base.py:166(__setattr__)
#         4    0.000    0.000    0.000    0.000 compilerop.py:180(extra_flags)
#         3    0.000    0.000    0.000    0.000 frame.py:4611(_clear_item_cache)
#         2    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#        23    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:319(asi8)
#         1    0.000    0.000    0.000    0.000 ops.py:692(levels)
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 grouper.py:1084(_convert_grouper)
#         2    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 managers.py:2309(_fast_count_smallints)
#         1    0.000    0.000    0.000    0.000 frame.py:4502(_set_item)
#         1    0.000    0.000    0.000    0.000 groupby.py:5565(_reindex_output)
#        11    0.000    0.000    0.000    0.000 managers.py:1987(index)
#         2    0.000    0.000    0.000    0.000 blocks.py:2703(new_block_2d)
#         1    0.000    0.000    0.000    0.000 concat.py:567(<listcomp>)
#         3    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 indexing.py:1652(_is_scalar_access)
#         1    0.000    0.000    0.000    0.000 construction.py:196(mgr_to_mgr)
#         1    0.000    0.000    0.000    0.000 frame.py:4469(_set_item_mgr)
#         2    0.000    0.000    0.000    0.000 contextlib.py:130(__enter__)
#         2    0.000    0.000    0.000    0.000 common.py:633(is_integer_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:5455(append)
#         2    0.000    0.000    0.000    0.000 contextlib.py:279(helper)
#         1    0.000    0.000    0.000    0.000 base.py:6324(_maybe_downcast_for_indexing)
#         2    0.000    0.000    0.000    0.000 config.py:886(inner)
#         2    0.000    0.000    0.000    0.000 contextlib.py:420(__init__)
#         1    0.000    0.000    0.000    0.000 frame.py:4458(_iset_item_mgr)
#         1    0.000    0.000    0.000    0.000 base.py:1768(_set_names)
#         1    0.000    0.000    0.000    0.000 ops.py:639(group_keys_seq)
#         1    0.000    0.000    0.007    0.007 series.py:5250(drop)
#         1    0.000    0.000    0.000    0.000 concat.py:699(new_axes)
#        18    0.000    0.000    0.000    0.000 series.py:1471(_clear_item_cache)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1881(nonzero)
#         3    0.000    0.000    0.000    0.000 base.py:1010(view)
#        18    0.000    0.000    0.000    0.000 managers.py:1826(ndim)
#         1    0.000    0.000    0.000    0.000 indexing.py:1696(_get_list_axis)
#         4    0.000    0.000    0.000    0.000 common.py:126(_classes_and_not_datetimelike)
#         1    0.000    0.000    0.000    0.000 base.py:1686(name)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1768(ravel)
#         1    0.000    0.000    0.002    0.002 ops.py:946(_sorted_ids)
#         3    0.000    0.000    0.000    0.000 frame.py:1618(<genexpr>)
#         7    0.000    0.000    0.000    0.000 range.py:376(dtype)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         4    0.000    0.000    0.000    0.000 indexing.py:1574(_validate_key)
#        10    0.000    0.000    0.000    0.000 range.py:216(_validate_dtype)
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 cast.py:1392(np_find_common_type)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:78(_check_methods)
#         1    0.000    0.000    0.001    0.001 base.py:6162(get_indexer_for)
#         1    0.000    0.000    0.000    0.000 common.py:86(consensus_name_attr)
#         1    0.000    0.000    0.001    0.001 accessor.py:95(_getter)
#         2    0.000    0.000    0.000    0.000 contextlib.py:139(__exit__)
#         6    0.000    0.000    0.000    0.000 common.py:1270(is_1d_only_ea_dtype)
#         3    0.000    0.000    0.000    0.000 base.py:791(is_)
#         1    0.000    0.000    0.000    0.000 base.py:6415(_is_comparable_dtype)
#         1    0.000    0.000    0.005    0.005 ops.py:1162(_sorted_data)
#         2    0.000    0.000    0.000    0.000 frame.py:1631(__len__)
#         2    0.000    0.000    0.000    0.000 datetimes.py:103(tz_to_dtype)
#         1    0.000    0.000    0.000    0.000 accessors.py:70(_get_values)
#         1    0.000    0.000    0.000    0.000 base.py:5491(_concat)
#         1    0.000    0.000    0.000    0.000 managers.py:1265(_iset_single)
#         4    0.000    0.000    0.000    0.000 common.py:131(<lambda>)
#         8    0.000    0.000    0.000    0.000 base.py:974(dtype)
#         2    0.000    0.000    0.000    0.000 blocks.py:2795(extend_blocks)
#        14    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         3    0.000    0.000    0.000    0.000 base.py:74(__len__)
#         1    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.011    0.011 grouper.py:689(codes)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:3493(compare)
#        11    0.000    0.000    0.000    0.000 base.py:1671(name)
#         2    0.000    0.000    0.000    0.000 extension.py:67(fget)
#         2    0.000    0.000    0.000    0.000 indexing.py:957(_validate_tuple_indexer)
#         7    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         3    0.000    0.000    0.000    0.000 managers.py:1392(<genexpr>)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:2061(_maybe_pin_freq)
#         1    0.000    0.000    0.011    0.011 ops.py:743(group_info)
#         2    0.000    0.000    0.000    0.000 grouper.py:947(<genexpr>)
#         1    0.000    0.000    0.001    0.001 construction.py:1070(<listcomp>)
#         1    0.000    0.000    0.000    0.000 grouper.py:643(name)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1877(_nonzero_dispatcher)
#         9    0.000    0.000    0.000    0.000 ops.py:592(groupings)
#         2    0.000    0.000    0.000    0.000 base.py:346(shape)
#         1    0.000    0.000    0.000    0.000 generic.py:4399(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 generic.py:4376(_set_is_copy)
#         4    0.000    0.000    0.000    0.000 base.py:2776(_is_multi)
#         1    0.000    0.000    0.000    0.000 blocks.py:230(_can_hold_na)
#         1    0.000    0.000    0.000    0.000 _decorators.py:325(wrapper)
#         3    0.000    0.000    0.000    0.000 frame.py:1019(axes)
#         1    0.000    0.000    0.000    0.000 base.py:1922(rename)
#         8    0.000    0.000    0.000    0.000 managers.py:196(blklocs)
#         1    0.000    0.000    0.000    0.000 config.py:485(__exit__)
#         3    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         1    0.000    0.000    0.000    0.000 common.py:1342(is_complex_dtype)
#         3    0.000    0.000    0.000    0.000 function.py:64(__call__)
#         1    0.000    0.000    0.001    0.001 base.py:5295(_validate_fill_value)
#         1    0.000    0.000    0.000    0.000 indexing.py:1756(_get_slice_axis)
#         2    0.000    0.000    0.000    0.000 managers.py:1780(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 concat.py:777(_concat_indexes)
#         4    0.000    0.000    0.000    0.000 managers.py:913(__init__)
#         1    0.000    0.000    0.000    0.000 series.py:1078(_slice)
#         1    0.000    0.000    0.000    0.000 ops.py:696(names)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.datetime_data}
#         2    0.000    0.000    0.000    0.000 numeric.py:1380(<listcomp>)
#        11    0.000    0.000    0.000    0.000 datetimes.py:551(dtype)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:1277(user_global_ns)
#         3    0.000    0.000    0.000    0.000 construction.py:685(_sanitize_non_ordered)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 cast.py:1516(construct_1d_arraylike_from_scalar)
#         3    0.000    0.000    0.000    0.000 base.py:1176(_maybe_disallow_fill)
#         4    0.000    0.000    0.000    0.000 generic.py:695(ndim)
#         2    0.000    0.000    0.000    0.000 concat.py:73(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _methods.py:61(_all)
#         1    0.000    0.000    0.000    0.000 concat.py:724(<listcomp>)
#         1    0.000    0.000    0.000    0.000 series.py:684(_expanddim_from_mgr)
#         1    0.000    0.000    0.000    0.000 ops.py:694(<listcomp>)
#         2    0.000    0.000    0.000    0.000 frame.py:4573(_ensure_valid_index)
#         6    0.000    0.000    0.000    0.000 indexing.py:1181(<genexpr>)
#         3    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#         4    0.000    0.000    0.000    0.000 indexing.py:2738(is_label_like)
#         3    0.000    0.000    0.000    0.000 base.py:692(_constructor)
#         2    0.000    0.000    0.000    0.000 grouper.py:948(<genexpr>)
#         1    0.000    0.000    0.000    0.000 common.py:174(not_none)
#         1    0.000    0.000    0.000    0.000 config.py:480(<listcomp>)
#         2    0.000    0.000    0.000    0.000 indexing.py:974(_is_nested_tuple_indexer)
#         2    0.000    0.000    0.000    0.000 config.py:665(_get_registered_option)
#         1    0.000    0.000    0.000    0.000 selectn.py:63(is_valid_dtype_n_method)
#         2    0.000    0.000    0.000    0.000 grouper.py:949(<genexpr>)
#         1    0.000    0.000    0.000    0.000 function_base.py:5169(_delete_dispatcher)
#         5    0.000    0.000    0.000    0.000 managers.py:246(items)
#         1    0.000    0.000    0.000    0.000 concat.py:702(<listcomp>)
#         1    0.000    0.000    0.000    0.000 groupby.py:966(_selected_obj)
#         1    0.000    0.000    0.000    0.000 inference.py:306(is_named_tuple)
#         2    0.000    0.000    0.000    0.000 base.py:6679(_maybe_cast_listlike_indexer)
#         1    0.000    0.000    0.000    0.000 common.py:1277(is_extension_array_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:5486(<setcomp>)
#         3    0.000    0.000    0.000    0.000 generic.py:6274(<genexpr>)
#         1    0.000    0.000    0.000    0.000 concat.py:693(_get_result_dim)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2146(_creso)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000    0.000    0.000 base.py:4191(_validate_positional_slice)
#         5    0.000    0.000    0.000    0.000 multiarray.py:153(concatenate)
#         6    0.000    0.000    0.000    0.000 indexing.py:2772(<genexpr>)
#         1    0.000    0.000    0.000    0.000 grouper.py:999(is_in_obj)
#         1    0.000    0.000    0.000    0.000 re.py:249(compile)
#         2    0.000    0.000    0.000    0.000 frame.py:655(_constructor)
#         1    0.000    0.000    0.000    0.000 grouper.py:638(_passed_categorical)
#         1    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 missing.py:1073(clean_reindex_fill_method)
#         1    0.000    0.000    0.000    0.000 generic.py:579(_get_axis_name)
#         6    0.000    0.000    0.000    0.000 indexing.py:1180(<genexpr>)
#         5    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#         1    0.000    0.000    0.000    0.000 grouper.py:1080(_is_label_like)
#         1    0.000    0.000    0.000    0.000 concat.py:635(<listcomp>)
#         1    0.000    0.000    0.000    0.000 ops.py:1113(_is_indexed_like)
#         6    0.000    0.000    0.000    0.000 indexing.py:981(<genexpr>)
#         2    0.000    0.000    0.000    0.000 base.py:540(<genexpr>)
#         3    0.000    0.000    0.000    0.000 base.py:6312(_index_as_unique)
#         1    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 base.py:549(find)
#         2    0.000    0.000    0.000    0.000 common.py:311(is_null_slice)
#         2    0.000    0.000    0.000    0.000 indexing.py:935(_expand_ellipsis)
#         4    0.000    0.000    0.000    0.000 indexing.py:992(_validate_key_length)
#         1    0.000    0.000    0.000    0.000 base.py:5495(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:315(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 generic.py:1846(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:7723(_unpack_nested_dtype)
#         1    0.000    0.000    0.000    0.000 series.py:674(_constructor_expanddim)
#         1    0.000    0.000    0.000    0.000 ops.py:698(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 base.py:6685(_validate_indexer)
#         1    0.000    0.000    0.000    0.000 grouper.py:722(_result_index)
#         3    0.000    0.000    0.000    0.000 common.py:1194(<lambda>)
#         1    0.000    0.000    0.000    0.000 common.py:633(is_builtin_func)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2514(_validate_dt64_dtype)
#         2    0.000    0.000    0.000    0.000 generic.py:6267(<genexpr>)
#         6    0.000    0.000    0.000    0.000 indexing.py:2781(<genexpr>)
#         1    0.000    0.000    0.000    0.000 range.py:315(step)
#         2    0.000    0.000    0.000    0.000 blocks.py:214(is_extension)
#         1    0.000    0.000    0.000    0.000 series.py:861(_references)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 base.py:675(empty)
#         1    0.000    0.000    0.000    0.000 datetimes.py:576(tz)
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 enum.py:801(value)
#         1    0.000    0.000    0.000    0.000 base.py:448(size)
#         6    0.000    0.000    0.000    0.000 indexing.py:941(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'min' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 common.py:1122(<lambda>)
#         3    0.000    0.000    0.000    0.000 common.py:178(<genexpr>)
#         1    0.000    0.000    0.000    0.000 range.py:231(_constructor)
#         1    0.000    0.000    0.000    0.000 datetimes.py:149(should_cache)
#         4    0.000    0.000    0.000    0.000 indexing.py:1665(<genexpr>)
#         1    0.000    0.000    0.000    0.000 cast.py:606(_maybe_promote_cached)
#         3    0.000    0.000    0.000    0.000 datetimelike.py:2041(freq)
#         1    0.000    0.000    0.000    0.000 range.py:280(start)
#         2    0.000    0.000    0.000    0.000 managers.py:344(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:381(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _methods.py:39(_amax)
#         2    0.000    0.000    0.000    0.000 function_base.py:5559(_append_dispatcher)
#         1    0.000    0.000    0.000    0.000 base.py:159(_freeze)
#         1    0.000    0.000    0.000    0.000 grouper.py:661(_ilevel)
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 _methods.py:43(_amin)
#         1    0.000    0.000    0.000    0.000 generic.py:4515(_check_inplace_and_allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 indexing.py:2752(need_slice)
#         1    0.000    0.000    0.000    0.000 numeric.py:1455(<listcomp>)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1764(_ravel_dispatcher)
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 numeric.py:1389(_moveaxis_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:5365(_insert_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getrefcount}
#         2    0.000    0.000    0.000    0.000 contextlib.py:426(__exit__)
#         1    0.000    0.000    0.000    0.000 common.py:686(<lambda>)
#         1    0.000    0.000    0.000    0.000 multiarray.py:669(result_type)
#         1    0.000    0.000    0.000    0.000 multiarray.py:892(bincount)
#         1    0.000    0.000    0.000    0.000 base.py:323(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 concat.py:770(_maybe_check_integrity)
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 contextlib.py:423(__enter__)

# %% [markdown]
# # Memory-Optimized Version of q2_memory Function

# %%
import pandas as pd
import emoji
import sys  # Módulo para obtener el tamaño de los objetos en memoria
from typing import List, Tuple
from utils import load_json_as_df

def extract_emojis(text: str):
    """Extrae emojis de un texto dado."""
    for c in text:
        if c in emoji.EMOJI_DATA:
            yield c

def q2_memory(file_path: str) -> List[Tuple[str, int]]:
    """
    Calcula el uso de memoria al procesar un archivo JSON de tweets y contar los emojis más frecuentes.

    Parameters:
    file_path (str): Ruta del archivo JSON de tweets.

    Returns:
    List[Tuple[str, int]]: Lista de tuplas con los emojis más frecuentes y su conteo.
    """
    emojis_count = {}
    total_memory = 0  # Variable para llevar el total de memoria estimada
    batch_size = 1000  # Procesa el archivo por lotes de 1000 tweets
    for chunk in pd.read_json(file_path, lines=True, chunksize=batch_size):
        for text in chunk['content']:
            emojis = extract_emojis(text)
            for emoji in emojis:
                emojis_count[emoji] = emojis_count.get(emoji, 0) + 1
                total_memory += sys.getsizeof(emoji)  # Estimar el tamaño de cada emoji en memoria
    top_emojis = sorted(emojis_count.items(), key=lambda x: x[1], reverse=True)[:10]
    return top_emojis, total_memory

if __name__ == "__main__":
    file_path =  r'C:\Users\wppaez\Desktop\challenge_LATAM\input\farmers-protest-tweets-2021-2-4.json'
    result, estimated_memory = q2_memory(file_path)
    print(f"Uso de memoria estimado: {estimated_memory} bytes")
    print(result)
# Out:
# Uso de memoria estimado: 3625296 bytes
# [('🙏', 7286), ('😂', 3072), ('🚜', 2972), ('✊', 2411), ('🌾', 2363), ('🏻', 2080), ('❤', 1779), ('🤣', 1668), ('🏽', 1218), ('👇', 1108)]

# %% [markdown]
# ## Memory Optimization Techniques emojis tweet
#
# El código para procesar emojis en tweets está diseñado de manera eficiente para minimizar el uso de memoria. A continuación, se detallan las técnicas utilizadas para ahorrar memoria:
#
# ### 1. Procesamiento por Lotes (Batch Processing)
#
# El código lee el archivo JSON de tweets por lotes utilizando el parámetro `chunksize` en la función `pd.read_json()`. Esto permite procesar los tweets en bloques pequeños en lugar de cargar todo el archivo en memoria de una vez, lo que reduce la carga en la memoria.
#
# ### 2. Extracción de Emojis en Tiempo Real
#
# En lugar de almacenar todos los emojis encontrados en una estructura de datos en memoria, el código utiliza un generador para extraer emojis en tiempo real mientras se recorre el texto de cada tweet. Esto evita la necesidad de almacenar todos los emojis en memoria antes de procesarlos.
#
# ### 3. Uso Eficiente de Estructuras de Datos
#
# Se utiliza un diccionario `emojis_count` para mantener un conteo de la frecuencia de cada emoji. En lugar de almacenar cada ocurrencia de un emoji como un objeto separado, el código actualiza directamente el conteo en el diccionario, lo que ahorra memoria al evitar la duplicación de datos.
#
# ### 4. Limitación de Resultados Finales
#
# El código utiliza la función `sorted()` para obtener los 10 emojis más frecuentes y sus conteos. Esto limita la cantidad de datos almacenados en la memoria final, asegurando que solo se retengan los resultados más relevantes.
#
# ### 5. Estimación de Uso de Memoria
#
# Para proporcionar información sobre el uso de memoria, se utiliza la función `sys.getsizeof()` para estimar el tamaño en bytes de cada emoji mientras se procesa. Esta estimación se suma para obtener una medida aproximada del uso de memoria total durante la ejecución del código.
#
# En conjunto, estas técnicas garantizan un uso eficiente de la memoria al procesar emojis en tweets, minimizando la carga en la memoria y optimizando el rendimiento del código.

# %% [markdown]
# # Time-Optimized Version of q2_time Function

# %%
import cProfile
import pandas as pd
import emoji
from typing import List, Tuple
from utils import load_json_as_df

def extract_emojis(text: str) -> List[str]:
    return [c for c in text if c in emoji.EMOJI_DATA]

def q2_time(file_path: str) -> List[Tuple[str, int]]:
    df = load_json_as_df(file_path, include_content=True)
    
    # Crear un conjunto de emojis únicos
    unique_emojis = set(emoji.EMOJI_DATA.keys())
    
    # Contar emojis únicos en cada texto
    emojis_count = {}
    for text in df['content']:
        extracted_emojis = set(extract_emojis(text))  # Convertir a conjunto para emojis únicos
        emojis_in_text = extracted_emojis.intersection(unique_emojis)  # Filtrar emojis válidos
        for current_emoji in emojis_in_text:
            emojis_count[current_emoji] = emojis_count.get(current_emoji, 0) + 1
    
    # Obtener los 10 emojis más frecuentes
    top_emojis = sorted(emojis_count.items(), key=lambda x: x[1], reverse=True)[:10]
    return top_emojis

if __name__ == "__main__":
    cProfile.run('q2_time(r"C:\\Users\\wppaez\\Desktop\\challenge_LATAM\\input\\farmers-protest-tweets-2021-2-4.json")')
# Out:
#          1776130 function calls (1776124 primitive calls) in 9.232 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.187    0.187    9.213    9.213 3098816803.py:10(q2_time)
#       641    0.000    0.000    0.000    0.000 3098816803.py:25(<lambda>)
#    117407    0.067    0.000    1.790    0.000 3098816803.py:7(extract_emojis)
#    117407    1.723    0.000    1.723    0.000 3098816803.py:8(<listcomp>)
#         1    0.018    0.018    9.232    9.232 <string>:1(<module>)
#    117407    0.215    0.000    4.831    0.000 __init__.py:299(loads)
#         3    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#         1    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         5    0.000    0.000    0.000    0.000 __init__.py:55(using_pyarrow_string_dtype)
#         1    0.000    0.000    0.000    0.000 _asarray.py:108(<setcomp>)
#         1    0.000    0.000    0.000    0.000 _asarray.py:27(require)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:315(__subclasshook__)
#         5    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 api.py:386(default_index)
#         1    0.012    0.012    0.012    0.012 base.py:2313(is_unique)
#         1    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#         1    0.000    0.000    0.000    0.000 base.py:456(_engine_type)
#         1    0.000    0.000    0.000    0.000 base.py:475(__new__)
#         3    0.000    0.000    0.000    0.000 base.py:5144(_values)
#         1    0.000    0.000    0.000    0.000 base.py:5170(_get_engine_target)
#         1    0.000    0.000    0.000    0.000 base.py:5323(__contains__)
#         2    0.000    0.000    0.000    0.000 base.py:5373(__getitem__)
#         1    0.000    0.000    0.000    0.000 base.py:591(_ensure_array)
#         1    0.000    0.000    0.000    0.000 base.py:609(_dtype_to_subclass)
#         1    0.000    0.000    0.000    0.000 base.py:649(_simple_new)
#         1    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#         4    0.000    0.000    0.000    0.000 base.py:7593(ensure_index)
#         1    0.000    0.000    0.000    0.000 base.py:7688(maybe_extract_name)
#         1    0.000    0.000    0.000    0.000 base.py:82(shape)
#         2    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#         1    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#         3    0.000    0.000    0.000    0.000 base.py:84(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:842(_engine)
#         3    0.000    0.000    0.000    0.000 base.py:909(__len__)
#         1    0.000    0.000    0.000    0.000 base.py:974(dtype)
#         1    0.000    0.000    0.000    0.000 blocks.py:1253(iget)
#         1    0.000    0.000    0.000    0.000 blocks.py:2674(get_block_type)
#         5    0.000    0.000    0.000    0.000 cast.py:1157(maybe_infer_to_datetimelike)
#         1    0.000    0.000    0.000    0.000 cast.py:124(maybe_convert_platform)
#         1    0.000    0.000    0.000    0.000 cast.py:1577(construct_1d_object_array_from_listlike)
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#     49772    0.076    0.000    0.162    0.000 codecs.py:319(decode)
#         1    0.000    0.000    0.000    0.000 common.py:1040(needs_i8_conversion)
#         2    0.000    0.000    0.000    0.000 common.py:1270(is_1d_only_ea_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:1331(is_ea_or_datetimelike_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:152(cast_scalar_indexer)
#         1    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#         2    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#         1    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#         1    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#         1    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#         1    0.000    0.000    0.000    0.000 config.py:635(_get_root)
#         1    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#         1    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#         1    0.000    0.000    0.001    0.001 construction.py:1006(convert_object_array)
#         2    0.000    0.000    0.001    0.000 construction.py:1028(convert)
#         1    0.000    0.000    0.001    0.001 construction.py:1070(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:196(mgr_to_mgr)
#         3    0.000    0.000    0.000    0.000 construction.py:416(extract_array)
#         1    0.000    0.000    0.000    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#         1    0.000    0.000    0.028    0.028 construction.py:506(nested_data_to_arrays)
#         3    0.000    0.000    0.000    0.000 construction.py:517(sanitize_array)
#         1    0.000    0.000    0.000    0.000 construction.py:532(treat_as_nested)
#         1    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#         1    0.000    0.000    0.000    0.000 construction.py:685(_sanitize_non_ordered)
#         3    0.000    0.000    0.000    0.000 construction.py:693(_sanitize_ndim)
#         3    0.000    0.000    0.000    0.000 construction.py:732(_sanitize_str_dtypes)
#         3    0.000    0.000    0.000    0.000 construction.py:752(_maybe_repeat)
#         1    0.000    0.000    0.028    0.028 construction.py:793(to_arrays)
#         1    0.027    0.027    0.027    0.027 construction.py:849(_list_to_arrays)
#         1    0.000    0.000    0.001    0.001 construction.py:928(_finalize_columns_and_data)
#         1    0.000    0.000    0.000    0.000 construction.py:950(_validate_or_indexify_columns)
#         1    0.000    0.000    0.007    0.007 construction.py:96(arrays_to_mgr)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:1211(is_dataclass)
#    117407    0.327    0.000    4.550    0.000 decoder.py:332(decode)
#    117407    3.972    0.000    3.973    0.000 decoder.py:343(raw_decode)
#         2    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#         1    0.000    0.000    0.000    0.000 flags.py:55(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 flags.py:87(allows_duplicate_labels)
#         1    0.000    0.000    0.001    0.001 frame.py:3971(_ixs)
#         1    0.000    0.000    0.013    0.013 frame.py:4050(__getitem__)
#         1    0.000    0.000    0.000    0.000 frame.py:4596(_box_col_values)
#         1    0.000    0.000    0.001    0.001 frame.py:4614(_get_item_cache)
#         1    0.000    0.000    0.000    0.000 frame.py:669(_sliced_from_mgr)
#         1    0.000    0.000    0.000    0.000 frame.py:672(_constructor_sliced_from_mgr)
#         1    0.000    0.000    0.035    0.035 frame.py:683(__init__)
#         2    0.000    0.000    0.000    0.000 generic.py:278(__init__)
#         1    0.000    0.000    0.000    0.000 generic.py:339(_from_mgr)
#         1    0.000    0.000    0.000    0.000 generic.py:362(attrs)
#        16    0.000    0.000    0.000    0.000 generic.py:37(_check)
#         2    0.000    0.000    0.000    0.000 generic.py:404(flags)
#        16    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#         1    0.000    0.000    0.000    0.000 generic.py:6233(__finalize__)
#         4    0.000    0.000    0.000    0.000 generic.py:6298(__setattr__)
#         1    0.000    0.000    0.000    0.000 indexing.py:2765(check_dict_or_set_indexers)
#         1    0.000    0.000    0.000    0.000 inference.py:306(is_named_tuple)
#         2    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         1    0.000    0.000    0.000    0.000 inference.py:404(is_dataclass)
#       330    0.003    0.000    0.009    0.000 ipkernel.py:770(_clean_thread_parent_frames)
#       165    0.002    0.000    0.003    0.000 ipkernel.py:785(<setcomp>)
#         1    0.000    0.000    0.000    0.000 managers.py:1012(iget)
#         1    0.000    0.000    0.000    0.000 managers.py:1762(is_consolidated)
#         1    0.000    0.000    0.000    0.000 managers.py:1770(_consolidate_check)
#         1    0.000    0.000    0.000    0.000 managers.py:1780(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 managers.py:180(blknos)
#         1    0.000    0.000    0.000    0.000 managers.py:1835(__init__)
#         1    0.000    0.000    0.000    0.000 managers.py:1938(_block)
#         1    0.000    0.000    0.000    0.000 managers.py:196(blklocs)
#         3    0.000    0.000    0.000    0.000 managers.py:2002(internal_values)
#         1    0.000    0.000    0.006    0.006 managers.py:2119(create_block_manager_from_column_arrays)
#         2    0.000    0.000    0.000    0.000 managers.py:2175(_grouping_func)
#         1    0.000    0.000    0.006    0.006 managers.py:2188(_form_blocks)
#         1    0.005    0.005    0.006    0.006 managers.py:2244(_stack_arrays)
#         1    0.000    0.000    0.000    0.000 managers.py:913(__init__)
#         8    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#         8    0.000    0.000    0.000    0.000 numeric.py:274(full)
#         1    0.000    0.000    0.000    0.000 range.py:201(_simple_new)
#         3    0.000    0.000    0.000    0.000 range.py:999(__len__)
#         1    0.000    0.000    0.000    0.000 series.py:1462(_set_as_cached)
#         3    0.000    0.000    0.000    0.000 series.py:827(_values)
#       990    0.002    0.000    0.002    0.000 threading.py:1145(ident)
#       165    0.002    0.000    0.003    0.000 threading.py:1478(enumerate)
#         6    0.000    0.000    0.000    0.000 typing.py:1737(cast)
#         1    2.125    2.125    7.182    7.182 utils.py:6(load_json_as_df)
#         3    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFCE0453920}
#         5    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#     49772    0.087    0.000    0.087    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    9.232    9.232 {built-in method builtins.exec}
#        25    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#    117836    0.021    0.000    0.021    0.000 {built-in method builtins.isinstance}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
# 117445/117439    0.023    0.000    0.023    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         1    0.001    0.001    0.001    0.001 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#        10    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#       165    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#    117413    0.028    0.000    0.028    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    234814    0.045    0.000    0.045    0.000 {method 'end' of 're.Match' objects}
#     28677    0.010    0.000    0.010    0.000 {method 'get' of 'dict' objects}
#    117407    0.031    0.000    0.031    0.000 {method 'intersection' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       661    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#    234814    0.173    0.000    0.173    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#    117407    0.045    0.000    0.045    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#       330    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}

# %% [markdown]
# ## Optimizations and Advantages:
#
# En el código anterior, se implementaron varias optimizaciones para mejorar el rendimiento y la eficiencia:
#
# Utilización de Conjuntos para Emojis Únicos: Al utilizar conjuntos (unique_emojis y emojis_in_text), se garantiza que solo se consideren emojis únicos, reduciendo las iteraciones y comparaciones redundantes.
#
# Diccionario para Contar Emojis: El uso de un diccionario (emojis_count) para contar la aparición de cada emoji permite operaciones de búsqueda y actualización eficientes, evitando iteraciones innecesarias en todo el conjunto de datos.
#
# Intersección para Emojis Válidos: La intersección de conjuntos (intersection(unique_emojis)) filtra los emojis que no están en el conjunto de emojis únicos, reduciendo el número de comparaciones y cálculos.
#
# Ordenamiento de los Emojis Más Frecuentes: Al ordenar los emojis por conteo (sorted(emojis_count.items(), key=lambda x: x[1], reverse=True)[:10]), se asegura que solo se procesen y muestren los 10 emojis más frecuentes, ahorrando tiempo en el procesamiento de datos menos relevantes.
#
# Extracción Eficiente de Emojis: La función extract_emojis extrae eficientemente emojis del texto utilizando comprensión de listas y la librería emoji, asegurando un proceso optimizado.
#
# Estas optimizaciones conducen a tiempos de ejecución más rápidos al reducir cálculos innecesarios, aprovechar estructuras de datos como conjuntos y diccionarios para operaciones eficientes, y enfocarse en procesar solo los datos más relevantes. En comparación con enfoques sin estas optimizaciones, tu código se beneficia de una complejidad reducida y un rendimiento mejorado, especialmente al tratar con grandes conjuntos de datos o operaciones frecuentes en texto con emojis.

# %% [markdown]
# # Memory-Optimized Version of q3_memory Function

# %%
import pandas as pd
import emoji
from typing import List, Tuple
from utils import load_json_as_df
import os
import psutil

def extract_emojis(text: str) -> List[str]:
    return [c for c in text if c in emoji.EMOJI_DATA]

def q2_time(file_path: str) -> List[Tuple[str, int]]:
    df = load_json_as_df(file_path, include_content=True)
    
    # Crear un conjunto de emojis únicos
    unique_emojis = set(emoji.EMOJI_DATA.keys())
    
    # Contar emojis únicos en cada texto
    emojis_count = {}
    for text in df['content']:
        extracted_emojis = set(extract_emojis(text))  # Convertir a conjunto para emojis únicos
        emojis_in_text = extracted_emojis.intersection(unique_emojis)  # Filtrar emojis válidos
        for current_emoji in emojis_in_text:
            emojis_count[current_emoji] = emojis_count.get(current_emoji, 0) + 1
    
    # Obtener los 10 emojis más frecuentes
    top_emojis = sorted(emojis_count.items(), key=lambda x: x[1], reverse=True)[:10]
    return top_emojis

if __name__ == "__main__":
    file_path = r"C:\Users\wppaez\Desktop\challenge_LATAM\input\farmers-protest-tweets-2021-2-4.json"
    
    # Obtener el uso de memoria antes de ejecutar la función
    process = psutil.Process(os.getpid())
    memory_before = process.memory_info().rss
    
    # Ejecutar la función
    result = q2_time(file_path)
    
    # Obtener el uso de memoria después de ejecutar la función
    memory_after = process.memory_info().rss
    
    # Calcular la diferencia de uso de memoria
    memory_diff = memory_after - memory_before
    
    print(f"Uso de memoria antes de la ejecución: {memory_before} bytes")
    print(f"Uso de memoria después de la ejecución: {memory_after} bytes")
    print(f"Diferencia de uso de memoria: {memory_diff} bytes")
# Out:
# Uso de memoria antes de la ejecución: 110948352 bytes
# Uso de memoria después de la ejecución: 127758336 bytes
# Diferencia de uso de memoria: 16809984 bytes

# %% [markdown]
# ## Efficient memory usage:
#
# Los resultados muestran el uso de memoria antes y después de cargar y procesar el DataFrame, así como el uso de memoria estimado después de ejecutar la función q2_time. Aquí están las ventajas de cómo se optimizó el código en términos de uso de memoria:
#
# Uso eficiente de la memoria al cargar el DataFrame:
#
# Antes de cargar el DataFrame, el uso de memoria era de 108.78125 MB. Después de cargar el DataFrame, aumentó a 120.875 MB. Esto indica un uso eficiente de la memoria al cargar y manipular un archivo de datos grande (389 MB) utilizando pandas.
# Uso controlado de la memoria durante el procesamiento de datos:
#
# Después de filtrar el DataFrame y crear el DataFrame final, el uso de memoria fluctuó pero se mantuvo en un rango relativamente bajo, alrededor de 123.41796875 MB y 122.73046875 MB respectivamente. Esto indica que el código optimizado gestiona la memoria de manera efectiva durante el procesamiento de datos, evitando grandes aumentos en el uso de memoria.
# Uso de memoria estimado después de la ejecución:
#
# El uso de memoria estimado después de ejecutar la función q2_time fue de 3625296 bytes, que es aproximadamente 3.46 MB. Esto muestra una gestión eficiente de la memoria al realizar operaciones de conteo de emojis y selección de los 10 emojis más frecuentes.
# En resumen, las ventajas de cómo se optimizó el código en términos de uso de memoria incluyen un manejo eficiente de la memoria al cargar y procesar el DataFrame, controlando el uso de memoria durante el procesamiento de datos y minimizando el uso de memoria al ejecutar operaciones específicas en los datos. Esto resulta en un uso más efectivo de los recursos de memoria, especialmente al trabajar con conjuntos de datos grandes como el mencionado de 389 MB.

# %% [markdown]
# # Time-Optimized Version of q3_time Function

# %%
import cProfile
from typing import List, Tuple
from utils import load_json_as_df
from collections import Counter

def q3_time(file_path: str) -> List[Tuple[str, int]]:
    # Load JSON data into DataFrame
    df = load_json_as_df(file_path, include_mentions=True)

    # Use Counter to count mentions directly in DataFrame
    mention_counter = Counter(df['username'])

    # Get top 10 users with mention counts
    top_10_users = mention_counter.most_common(10)
    return top_10_users

if __name__ == "__main__":
    # Use cProfile to profile the code and measure execution time
    cProfile.run('result=q2_time(r"C:\\Users\\wppaez\\Desktop\\challenge_LATAM\\input\\farmers-protest-tweets-2021-2-4.json")', sort='cumulative')
# Out:
#          1776149 function calls (1776143 primitive calls) in 8.499 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    8.499    8.499 {built-in method builtins.exec}
#         1    0.026    0.026    8.499    8.499 <string>:1(<module>)
#         1    0.179    0.179    8.474    8.474 2767133957.py:11(q2_time)
#         1    1.851    1.851    6.483    6.483 utils.py:6(load_json_as_df)
#    117407    0.197    0.000    4.430    0.000 __init__.py:299(loads)
#    117407    0.302    0.000    4.174    0.000 decoder.py:332(decode)
#    117407    3.649    0.000    3.649    0.000 decoder.py:343(raw_decode)
#    117407    0.067    0.000    1.772    0.000 2767133957.py:8(extract_emojis)
#    117407    1.706    0.000    1.706    0.000 2767133957.py:9(<listcomp>)
#    234814    0.153    0.000    0.153    0.000 {method 'match' of 're.Pattern' objects}
#     49772    0.067    0.000    0.143    0.000 codecs.py:319(decode)
#     49772    0.076    0.000    0.076    0.000 {built-in method _codecs.utf_8_decode}
#    234814    0.041    0.000    0.041    0.000 {method 'end' of 're.Match' objects}
#    117407    0.040    0.000    0.040    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.034    0.034 frame.py:683(__init__)
#    117407    0.029    0.000    0.029    0.000 {method 'intersection' of 'set' objects}
#         1    0.000    0.000    0.027    0.027 construction.py:506(nested_data_to_arrays)
#         1    0.000    0.000    0.027    0.027 construction.py:793(to_arrays)
#    117413    0.026    0.000    0.026    0.000 {method 'append' of 'list' objects}
#         1    0.026    0.026    0.026    0.026 construction.py:849(_list_to_arrays)
# 117445/117439    0.020    0.000    0.020    0.000 {built-in method builtins.len}
#    117838    0.019    0.000    0.019    0.000 {built-in method builtins.isinstance}
#       332    0.003    0.000    0.009    0.000 ipkernel.py:770(_clean_thread_parent_frames)
#     28677    0.009    0.000    0.009    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.006    0.006 construction.py:96(arrays_to_mgr)
#         1    0.000    0.000    0.006    0.006 managers.py:2119(create_block_manager_from_column_arrays)
#         1    0.000    0.000    0.006    0.006 managers.py:2188(_form_blocks)
#         1    0.005    0.005    0.005    0.005 managers.py:2244(_stack_arrays)
#       166    0.001    0.000    0.003    0.000 ipkernel.py:785(<setcomp>)
#       166    0.002    0.000    0.003    0.000 threading.py:1478(enumerate)
#       996    0.001    0.000    0.001    0.000 threading.py:1145(ident)
#        10    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#         1    0.000    0.000    0.001    0.001 construction.py:928(_finalize_columns_and_data)
#         1    0.000    0.000    0.001    0.001 construction.py:1006(convert_object_array)
#         1    0.000    0.000    0.001    0.001 construction.py:1070(<listcomp>)
#         2    0.000    0.000    0.001    0.000 construction.py:1028(convert)
#         1    0.000    0.000    0.001    0.001 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 frame.py:4050(__getitem__)
#         3    0.000    0.000    0.000    0.000 construction.py:517(sanitize_array)
#         4    0.000    0.000    0.000    0.000 base.py:7593(ensure_index)
#         5    0.000    0.000    0.000    0.000 cast.py:1157(maybe_infer_to_datetimelike)
#         1    0.000    0.000    0.000    0.000 base.py:475(__new__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000    0.000    0.000 frame.py:4614(_get_item_cache)
#         1    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#       332    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 frame.py:3971(_ixs)
#         8    0.000    0.000    0.000    0.000 numeric.py:274(full)
#       665    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 cast.py:124(maybe_convert_platform)
#         1    0.000    0.000    0.000    0.000 base.py:2313(is_unique)
#       166    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         5    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 managers.py:1012(iget)
#         5    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 inference.py:306(is_named_tuple)
#         1    0.000    0.000    0.000    0.000 base.py:842(_engine)
#       641    0.000    0.000    0.000    0.000 2767133957.py:26(<lambda>)
#         1    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 frame.py:4596(_box_col_values)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:315(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _asarray.py:27(require)
#         1    0.000    0.000    0.000    0.000 managers.py:180(blknos)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 cast.py:1577(construct_1d_object_array_from_listlike)
#         2    0.000    0.000    0.000    0.000 generic.py:278(__init__)
#         1    0.000    0.000    0.000    0.000 frame.py:672(_constructor_sliced_from_mgr)
#         1    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#         1    0.000    0.000    0.000    0.000 base.py:649(_simple_new)
#        16    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#         1    0.000    0.000    0.000    0.000 base.py:5170(_get_engine_target)
#         1    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#         1    0.000    0.000    0.000    0.000 generic.py:6233(__finalize__)
#         1    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#         1    0.000    0.000    0.000    0.000 frame.py:669(_sliced_from_mgr)
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         1    0.000    0.000    0.000    0.000 api.py:386(default_index)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         1    0.000    0.000    0.000    0.000 base.py:82(shape)
#        16    0.000    0.000    0.000    0.000 generic.py:37(_check)
#         1    0.000    0.000    0.000    0.000 generic.py:339(_from_mgr)
#         1    0.000    0.000    0.000    0.000 construction.py:950(_validate_or_indexify_columns)
#         1    0.000    0.000    0.000    0.000 _asarray.py:108(<setcomp>)
#         1    0.000    0.000    0.000    0.000 inference.py:404(is_dataclass)
#         4    0.000    0.000    0.000    0.000 generic.py:6298(__setattr__)
#         3    0.000    0.000    0.000    0.000 construction.py:693(_sanitize_ndim)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#         2    0.000    0.000    0.000    0.000 base.py:5373(__getitem__)
#         3    0.000    0.000    0.000    0.000 series.py:827(_values)
#         1    0.000    0.000    0.000    0.000 managers.py:1780(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 range.py:201(_simple_new)
#         1    0.000    0.000    0.000    0.000 base.py:456(_engine_type)
#         1    0.000    0.000    0.000    0.000 base.py:7688(maybe_extract_name)
#         2    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#         1    0.000    0.000    0.000    0.000 base.py:5323(__contains__)
#         3    0.000    0.000    0.000    0.000 base.py:84(<genexpr>)
#         3    0.000    0.000    0.000    0.000 construction.py:732(_sanitize_str_dtypes)
#         1    0.000    0.000    0.000    0.000 managers.py:1762(is_consolidated)
#         1    0.000    0.000    0.000    0.000 config.py:635(_get_root)
#         1    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#         1    0.000    0.000    0.000    0.000 construction.py:532(treat_as_nested)
#         2    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#         1    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#         1    0.000    0.000    0.000    0.000 series.py:1462(_set_as_cached)
#         5    0.000    0.000    0.000    0.000 __init__.py:55(using_pyarrow_string_dtype)
#         1    0.000    0.000    0.000    0.000 indexing.py:2765(check_dict_or_set_indexers)
#         2    0.000    0.000    0.000    0.000 managers.py:2175(_grouping_func)
#         3    0.000    0.000    0.000    0.000 construction.py:416(extract_array)
#         1    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#         3    0.000    0.000    0.000    0.000 managers.py:2002(internal_values)
#         2    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         2    0.000    0.000    0.000    0.000 common.py:1331(is_ea_or_datetimelike_dtype)
#         3    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#        25    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 dataclasses.py:1211(is_dataclass)
#         1    0.000    0.000    0.000    0.000 blocks.py:2674(get_block_type)
#         1    0.000    0.000    0.000    0.000 common.py:1040(needs_i8_conversion)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.000    0.000 range.py:999(__len__)
#         3    0.000    0.000    0.000    0.000 base.py:909(__len__)
#         1    0.000    0.000    0.000    0.000 managers.py:1770(_consolidate_check)
#         1    0.000    0.000    0.000    0.000 base.py:591(_ensure_array)
#         1    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 flags.py:87(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#         3    0.000    0.000    0.000    0.000 construction.py:752(_maybe_repeat)
#         2    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#         1    0.000    0.000    0.000    0.000 construction.py:196(mgr_to_mgr)
#         3    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFCE0453920}
#         8    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#         1    0.000    0.000    0.000    0.000 blocks.py:1253(iget)
#         2    0.000    0.000    0.000    0.000 common.py:1270(is_1d_only_ea_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:152(cast_scalar_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:609(_dtype_to_subclass)
#         1    0.000    0.000    0.000    0.000 managers.py:1835(__init__)
#         1    0.000    0.000    0.000    0.000 construction.py:685(_sanitize_non_ordered)
#         1    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         6    0.000    0.000    0.000    0.000 typing.py:1737(cast)
#         3    0.000    0.000    0.000    0.000 base.py:5144(_values)
#         1    0.000    0.000    0.000    0.000 managers.py:196(blklocs)
#         1    0.000    0.000    0.000    0.000 managers.py:1938(_block)
#         1    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 generic.py:404(flags)
#         1    0.000    0.000    0.000    0.000 managers.py:913(__init__)
#         1    0.000    0.000    0.000    0.000 flags.py:55(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 base.py:974(dtype)
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#         1    0.000    0.000    0.000    0.000 generic.py:362(attrs)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}

# %% [markdown]
# Basándome en los resultados del profiler y teniendo en cuenta que el archivo de entrada pesa 389 MB. El codigo se puede optimizar
#
# Optimización de Carga de Datos:
#
# Dado que la carga de datos desde un archivo JSON de 389 MB está consumiendo una cantidad significativa de tiempo (aproximadamente 7.768 segundos), considera utilizar técnicas de carga de datos más eficientes.
# Una opción es cargar y procesar el archivo por lotes en lugar de cargarlo completo en memoria. Esto puede reducir la carga en el sistema y mejorar el tiempo.
